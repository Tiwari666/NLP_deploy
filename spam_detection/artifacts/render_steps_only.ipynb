# %% [markdown]
# ## First publish the project in the GitHub to deply the application in the Render
#
# Go to https://github.com
#
# Create repository
#
# Open VS Code terminal in FlaskApp/ folder and run the following in the termianl:
#
# cd C:\Users\naren\Desktop\New_DS\spam_detection\FlaskApp
#
# Then run:
#
# ++++++++++++++++++++++++run one by one###
#
# git init
#
# git remote add origin https://github.com/Tiwari666/NLP_spam_detect_deploy.git
#
# git add .
#
# git commit -m "Initial commit"
#
# git pull origin main --allow-unrelated-histories
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ### To Exit Vim and Continue the Merge:
#
#  Just press these keys in order:
#
# Esc
#
# Type :wq
#
# Press Enter
#
# That means:
#
# w → write (save)
#
# q → quit
#
# ++++++++++++++++
#
# git push -u origin main

# %% [markdown]
# # Start the Render ( online/web deployment)
#
# ### step 1
#
# Login to https://render.com
#
# Sign up or log in with your GitHub account
#
# ### step 2
#
#  Click "New Web Service" under Web Services
# (It's the middle box in the first row)
#
# ### step 3
#
# Connect to GitHub: aauthorize Render
#
# ## step 4

# %% [markdown]
# # Steps to Push the Full Project:
#
# 1. Go to your root project folder:
#
# cd C:\Users\naren\Desktop\New_DS\spam_detection
#
# 2. Reconnect Git to the same GitHub repo:
#
# git init
#
# git remote add origin https://github.com/Tiwari666/NLP_spam_detect_deploy.git
#
# 21.  if it says remote already exists, run:
#
# git remote set-url origin https://github.com/Tiwari666/NLP_spam_detect_deploy.git
#
#
# 3. Add and push the full project:
#
# git add .
#
# git commit -m "Updated full project: notebooks, data, and web app"
#
# git push -u origin main --force
#
# 4. Force Git to include everything ( Optional: if FlaskApp directory or anyone does not open after its publication on GitHub)
#
# git add -A
#
# git commit -m "Fix: ensure FlaskApp and all files are pushed"
#
# git push -u origin main --force
#
#
# 5. Re-track everything inside FlaskApp (Optional)
#
# git add FlaskApp -f
#
# git commit -m "Force add all FlaskApp contents"
#
# git push origin main
#
# 6. cd FlaskApp
#
# 7. Add a .keep file in empty folders
#
# echo "# keep this folder" > FlaskApp/static/.keep
#
# 8. Re-stage and force push again
#
# git add -A
#
# git commit -m "Fix: Force add visible files in FlaskApp"
#
# git push origin main --force

# %% [markdown]
# # If all directories do not work, let's start from the begining as follows:
#
#  1. Open terminal at your project root
#
#  cd C:\Users\naren\Desktop\New_DS\spam_detection
#
#  2. Remove old Git (if any) and re-init
#
# rmdir /s /q .git
#
# git init
#
# 3. Connect to new GitHub repo
#
# git remote add origin https://github.com/Tiwari666/full_spam_detector_deploy.git
#
#
# 4. Optional: keep empty folders visible
#
# echo "# keep" > FlaskApp/static/.keep
#
#  5. Add everything to Git
#
#  git add -A
#
# 6. Commit your work
#
# git commit -m "Initial full project: notebooks, data, and web app"
#
#
#
# 7. Push to GitHub (forcefully sync)
#
# git branch -M main
#
# git push -u origin main --force

# %% [markdown]
# # Final Render Setup (Web Service)

# %% [markdown]
# Click the repo:  Tiwari666 / NLP_deploy to select it
#
# | Field              | What to Enter                                      |
# | ------------------ | -------------------------------------------------- |
# | **Name**           | `nlp-spam-detector-deploy`  |
# | **Language**       | `Python 3`                    |
# | **Branch**         | `main` (✔ default is good)                         |
# | **Region**         | `Oregon (US West)` (✔ fine)                        |
# | **Root Directory** | `spam_detection/FlaskApp` ✅                        |
# | **Build Command**  | `pip install -r ../requirements.txt` ✅             |
# | **Start Command**  | `python app.py` ✅                                  |
# | **Instance Type**  | `Free` (✔ pick this if you're testing or learning) |
